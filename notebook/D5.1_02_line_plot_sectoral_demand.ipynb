# %% [markdown]
# # Line plot sectoral demand and feedstock supply

# %%
# Data modification
import pandas as pd
import numpy as np
import pyam

# Geospatial
import geopandas as gpd

# System
from pathlib import Path
import os

# Plotting
import matplotlib.pyplot as plt

# Ignore future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Output directory

# %%
out_dir = Path.cwd() / ".." / "output_data"

# %%
out_fig_dir = Path.cwd() / ".." / "output_figures"

# %%
input_dir = Path.cwd() / ".." / "input_data"

# Get a list of EU countries
sheets_dict = pd.read_excel(f"{input_dir}/FN_WP5_Feedstocks_High_Bioenergy_v2_shared.xlsx", sheet_name=None)

excluded_sheets = {"Cover", "info"}
eu_countries = [k for k in sheets_dict.keys() if k not in excluded_sheets]

# %%
# Make output_dir for each country
for iso in eu_countries:
    iso_path = os.path.join(out_fig_dir, iso)
    
    try:
        os.mkdir(iso_path)
    
    except FileExistsError:
        # If directory already exists
        pass

# %% [markdown]
# # Scenario data

# %%
# Scenario data is a processed dataset, it is stored in output_data directory
master_df = pyam.IamDataFrame(pd.read_csv(f"{input_dir}/master_scenarios_aggregated.csv"))

# %% [markdown]
# # Calculate total bioenergy demand

# %%
sectoral_demand = [
    "Electricity And District Heat Demand",
    "Household Demand",
    "Industry Demand",
    "Tertiary And Other Demand",
    "Transport Demand"
]

# %%
for v in sectoral_demand:
    master_df.rename(
        variable={v : f"Bioenergy Demand|{v}"},
        inplace=True
    )

# %%
master_df.filter(
    variable="*Demand",
).variable
# Out:
# ['Bioenergy Demand|Electricity And District Heat Demand',
#  'Bioenergy Demand|Household Demand',
#  'Bioenergy Demand|Industry Demand',
#  'Bioenergy Demand|Tertiary And Other Demand',
#  'Bioenergy Demand|Transport Demand']

# %%
calc_total_demand = master_df.filter(
    variable="*Demand",
)

total_demand = calc_total_demand.aggregate("Bioenergy Demand")

# %%
# Expected = (168, 8)
total_demand.timeseries().shape
# Out:
# (150, 8)

# %%
# Combine to master_df
master_df = pyam.concat([master_df, total_demand])

# %%
# Expected = (41328, 8)
master_df.timeseries().shape
# Out:
# (31044, 8)

# %%
# Total feedstock supply == total bioenergy demand, so we don't need to calculate it again

# %% [markdown]
# # Line plot

# %%
# Scaled to total bioenergy demand at a national level

sel_var = master_df.filter(variable="Bioenergy Demand*").variable

for v in sel_var:
    fig, ax = plt.subplots(figsize=(9, 6))

    data = master_df.filter(variable=v, region="EU27", unit="EJ")
    data.plot(color="scenario", ax=ax, linewidth=3)

    if v != "Bioenergy Demand":
        strip = v.split("|")
        title = strip[1].capitalize()
    
    else:
        title = v

    ax.set(
        title=f"{title} across scenarios in EU27",
        ylabel="Feedstock consumption (EJ)",
        xlabel="Year"
    )

    max_across_scene = (
        master_df
        .filter(variable="Bioenergy Demand", region="EU27", unit="EJ")
        .timeseries()
        .max(axis=1)
    )
    # get_y_max = max_across_scene.max() + 2

    # # Set ylim
    # ax.set_ylim(0, get_y_max)

    # plt.savefig(f"{out_fig_dir}/EU27/{title}_EU27_across_scenarios.png", dpi=300)

# %%
sel_var = master_df.filter(variable="Bioenergy Demand*").variable

data = master_df.filter(
    variable="Bioenergy Demand", 
    region="CY", 
    unit="EJ"
)

# %%
data.timeseries()
# Out:
#                                                         2015      2020  \
# model     scenario    region variable         unit
# D5.1 Data BioEnerHigh CY     Bioenergy Demand EJ    0.003453  0.003447
#           BioEnerLow  CY     Bioenergy Demand EJ    0.003453  0.003443
#           LimFor      CY     Bioenergy Demand EJ    0.003453  0.003443
#
#                                                         2025      2030  \
# model     scenario    region variable         unit
# D5.1 Data BioEnerHigh CY     Bioenergy Demand EJ    0.005285  0.009726
#           BioEnerLow  CY     Bioenergy Demand EJ    0.005903  0.009926
#           LimFor      CY     Bioenergy Demand EJ    0.005111  0.009960
#
#                                                         2035      2040  \
# model     scenario    region variable         unit
# D5.1 Data BioEnerHigh CY     Bioenergy Demand EJ    0.015194  0.021926
#           BioEnerLow  CY     Bioenergy Demand EJ    0.014327  0.021300
#           LimFor      CY     Bioenergy Demand EJ    0.014555  0.019974
#
#                                                         2045      2050
# model     scenario    region variable         unit
# D5.1 Data BioEnerHigh CY     Bioenergy Demand EJ    0.029124  0.033905
#           BioEnerLow  CY     Bioenergy Demand EJ    0.028297  0.033712
#           LimFor      CY     Bioenergy Demand EJ    0.026555  0.031090

# %%
data.plot()
# Out:
# <Axes: title={'center': 'model: D5.1 Data - region: CY - variable: Bioenergy Demand'}, xlabel='Year', ylabel='EJ'>

# %%
# Not scaled to total bioenergy demand at a national level

sel_var = master_df.filter(variable="Bioenergy Demand*").variable

for v in sel_var:

    for reg in master_df.region:

        fig, ax = plt.subplots(figsize=(9, 6))
        data = master_df.filter(variable=v, region=reg, unit="EJ")
        data.plot(ax=ax, color="scenario", linewidth=2)

        if v != "Bioenergy Demand":
            strip = v.split("|")
            title = strip[1].capitalize()

        else:
            title = v.capitalize()

        ax.set(
            title=f"{title} across scenarios in {reg}",
            ylabel="Feedstock consumption (EJ)",
            xlabel="Year"
        )

        max_across_scene = data.timeseries().max(axis=1)
        upper_lim = max_across_scene.max() * 0.1
        get_y_max = max_across_scene.max() + upper_lim

        # Set ylim
        ax.set_ylim(0, get_y_max)

        plt.savefig(f"{out_fig_dir}/{reg}/{title}_across_scenarios.png", dpi=300)
        print("Check the figure in", f"../output_figures/{reg}/{title}...")

        plt.close()
# Out:
# Check the figure in ../output_figures/AT/Bioenergy demand...
# Check the figure in ../output_figures/BE/Bioenergy demand...
# Check the figure in ../output_figures/BG/Bioenergy demand...
# Check the figure in ../output_figures/CY/Bioenergy demand...
# Check the figure in ../output_figures/CZ/Bioenergy demand...
# Check the figure in ../output_figures/DE/Bioenergy demand...
# Check the figure in ../output_figures/DK/Bioenergy demand...
# Check the figure in ../output_figures/EE/Bioenergy demand...
# Check the figure in ../output_figures/EL/Bioenergy demand...
# Check the figure in ../output_figures/ES/Bioenergy demand...
# Check the figure in ../output_figures/EU27/Bioenergy demand...
# Check the figure in ../output_figures/FI/Bioenergy demand...
# Check the figure in ../output_figures/FR/Bioenergy demand...
# Check the figure in ../output_figures/HR/Bioenergy demand...
# Check the figure in ../output_figures/HU/Bioenergy demand...
# Check the figure in ../output_figures/IE/Bioenergy demand...
# Check the figure in ../output_figures/IT/Bioenergy demand...
# Check the figure in ../output_figures/LA/Bioenergy demand...
# Check the figure in ../output_figures/LI/Bioenergy demand...
# Check the figure in ../output_figures/LX/Bioenergy demand...
# Check the figure in ../output_figures/MT/Bioenergy demand...
# Check the figure in ../output_figures/NL/Bioenergy demand...
# Check the figure in ../output_figures/PL/Bioenergy demand...
# Check the figure in ../output_figures/PT/Bioenergy demand...
# Check the figure in ../output_figures/RO/Bioenergy demand...
# Check the figure in ../output_figures/SE/Bioenergy demand...
# Check the figure in ../output_figures/SI/Bioenergy demand...
# Check the figure in ../output_figures/SK/Bioenergy demand...
# Check the figure in ../output_figures/AT/Electricity and district heat demand...
# Check the figure in ../output_figures/BE/Electricity and district heat demand...
# Check the figure in ../output_figures/BG/Electricity and district heat demand...
# Check the figure in ../output_figures/CY/Electricity and district heat demand...
# Check the figure in ../output_figures/CZ/Electricity and district heat demand...
# Check the figure in ../output_figures/DE/Electricity and district heat demand...
# Check the figure in ../output_figures/DK/Electricity and district heat demand...
# Check the figure in ../output_figures/EE/Electricity and district heat demand...
# Check the figure in ../output_figures/EL/Electricity and district heat demand...
# Check the figure in ../output_figures/ES/Electricity and district heat demand...
# Check the figure in ../output_figures/EU27/Electricity and district heat demand...
# Check the figure in ../output_figures/FI/Electricity and district heat demand...
# Check the figure in ../output_figures/FR/Electricity and district heat demand...
# Check the figure in ../output_figures/HR/Electricity and district heat demand...
# Check the figure in ../output_figures/HU/Electricity and district heat demand...
# Check the figure in ../output_figures/IE/Electricity and district heat demand...
# Check the figure in ../output_figures/IT/Electricity and district heat demand...
# Check the figure in ../output_figures/LA/Electricity and district heat demand...
# Check the figure in ../output_figures/LI/Electricity and district heat demand...
# Check the figure in ../output_figures/LX/Electricity and district heat demand...
# Check the figure in ../output_figures/MT/Electricity and district heat demand...
# Check the figure in ../output_figures/NL/Electricity and district heat demand...
# Check the figure in ../output_figures/PL/Electricity and district heat demand...
# Check the figure in ../output_figures/PT/Electricity and district heat demand...
# Check the figure in ../output_figures/RO/Electricity and district heat demand...
# Check the figure in ../output_figures/SE/Electricity and district heat demand...
# Check the figure in ../output_figures/SI/Electricity and district heat demand...
# Check the figure in ../output_figures/SK/Electricity and district heat demand...
# Check the figure in ../output_figures/AT/Household demand...
# Check the figure in ../output_figures/BE/Household demand...
# Check the figure in ../output_figures/BG/Household demand...
# Check the figure in ../output_figures/CY/Household demand...
# Check the figure in ../output_figures/CZ/Household demand...
# Check the figure in ../output_figures/DE/Household demand...
# Check the figure in ../output_figures/DK/Household demand...
# Check the figure in ../output_figures/EE/Household demand...
# Check the figure in ../output_figures/EL/Household demand...
# Check the figure in ../output_figures/ES/Household demand...
# Check the figure in ../output_figures/EU27/Household demand...
# Check the figure in ../output_figures/FI/Household demand...
# Check the figure in ../output_figures/FR/Household demand...
# Check the figure in ../output_figures/HR/Household demand...
# Check the figure in ../output_figures/HU/Household demand...
# Check the figure in ../output_figures/IE/Household demand...
# Check the figure in ../output_figures/IT/Household demand...
# Check the figure in ../output_figures/LA/Household demand...
# Check the figure in ../output_figures/LI/Household demand...
# Check the figure in ../output_figures/LX/Household demand...
# Check the figure in ../output_figures/MT/Household demand...
# Check the figure in ../output_figures/NL/Household demand...
# Check the figure in ../output_figures/PL/Household demand...
# Check the figure in ../output_figures/PT/Household demand...
# Check the figure in ../output_figures/RO/Household demand...
# Check the figure in ../output_figures/SE/Household demand...
# Check the figure in ../output_figures/SI/Household demand...
# Check the figure in ../output_figures/SK/Household demand...
# Check the figure in ../output_figures/AT/Industry demand...
# Check the figure in ../output_figures/BE/Industry demand...
# Check the figure in ../output_figures/BG/Industry demand...
# Check the figure in ../output_figures/CY/Industry demand...
# Check the figure in ../output_figures/CZ/Industry demand...
# Check the figure in ../output_figures/DE/Industry demand...
# Check the figure in ../output_figures/DK/Industry demand...
# Check the figure in ../output_figures/EE/Industry demand...
# Check the figure in ../output_figures/EL/Industry demand...
# Check the figure in ../output_figures/ES/Industry demand...
# Check the figure in ../output_figures/EU27/Industry demand...
# Check the figure in ../output_figures/FI/Industry demand...
# Check the figure in ../output_figures/FR/Industry demand...
# Check the figure in ../output_figures/HR/Industry demand...
# Check the figure in ../output_figures/HU/Industry demand...
# Check the figure in ../output_figures/IE/Industry demand...
# Check the figure in ../output_figures/IT/Industry demand...
# Check the figure in ../output_figures/LA/Industry demand...
# Check the figure in ../output_figures/LI/Industry demand...
# Check the figure in ../output_figures/LX/Industry demand...
# Check the figure in ../output_figures/MT/Industry demand...
# Check the figure in ../output_figures/NL/Industry demand...
# Check the figure in ../output_figures/PL/Industry demand...
# Check the figure in ../output_figures/PT/Industry demand...
# Check the figure in ../output_figures/RO/Industry demand...
# Check the figure in ../output_figures/SE/Industry demand...
# Check the figure in ../output_figures/SI/Industry demand...
# Check the figure in ../output_figures/SK/Industry demand...
# Check the figure in ../output_figures/AT/Tertiary and other demand...
# Check the figure in ../output_figures/BE/Tertiary and other demand...
# Check the figure in ../output_figures/BG/Tertiary and other demand...
# Check the figure in ../output_figures/CY/Tertiary and other demand...
# Check the figure in ../output_figures/CZ/Tertiary and other demand...
# Check the figure in ../output_figures/DE/Tertiary and other demand...
# Check the figure in ../output_figures/DK/Tertiary and other demand...
# Check the figure in ../output_figures/EE/Tertiary and other demand...
# Check the figure in ../output_figures/EL/Tertiary and other demand...
# Check the figure in ../output_figures/ES/Tertiary and other demand...
# Check the figure in ../output_figures/EU27/Tertiary and other demand...
# Check the figure in ../output_figures/FI/Tertiary and other demand...
# Check the figure in ../output_figures/FR/Tertiary and other demand...
# Check the figure in ../output_figures/HR/Tertiary and other demand...
# Check the figure in ../output_figures/HU/Tertiary and other demand...
# Check the figure in ../output_figures/IE/Tertiary and other demand...
# Check the figure in ../output_figures/IT/Tertiary and other demand...
# Check the figure in ../output_figures/LA/Tertiary and other demand...
# Check the figure in ../output_figures/LI/Tertiary and other demand...
# Check the figure in ../output_figures/LX/Tertiary and other demand...
# Check the figure in ../output_figures/MT/Tertiary and other demand...
# Check the figure in ../output_figures/NL/Tertiary and other demand...
# Check the figure in ../output_figures/PL/Tertiary and other demand...
# Check the figure in ../output_figures/PT/Tertiary and other demand...
# Check the figure in ../output_figures/RO/Tertiary and other demand...
# Check the figure in ../output_figures/SE/Tertiary and other demand...
# Check the figure in ../output_figures/SI/Tertiary and other demand...
# Check the figure in ../output_figures/SK/Tertiary and other demand...
# Check the figure in ../output_figures/AT/Transport demand...
# Check the figure in ../output_figures/BE/Transport demand...
# Check the figure in ../output_figures/BG/Transport demand...
# Check the figure in ../output_figures/CY/Transport demand...
# Check the figure in ../output_figures/CZ/Transport demand...
# Check the figure in ../output_figures/DE/Transport demand...
# Check the figure in ../output_figures/DK/Transport demand...
# Check the figure in ../output_figures/EE/Transport demand...
# Check the figure in ../output_figures/EL/Transport demand...
# Check the figure in ../output_figures/ES/Transport demand...
# Check the figure in ../output_figures/EU27/Transport demand...
# Check the figure in ../output_figures/FI/Transport demand...
# Check the figure in ../output_figures/FR/Transport demand...
# Check the figure in ../output_figures/HR/Transport demand...
# Check the figure in ../output_figures/HU/Transport demand...
# Check the figure in ../output_figures/IE/Transport demand...
# Check the figure in ../output_figures/IT/Transport demand...
# Check the figure in ../output_figures/LA/Transport demand...
# Check the figure in ../output_figures/LI/Transport demand...
# Check the figure in ../output_figures/LX/Transport demand...
# Check the figure in ../output_figures/MT/Transport demand...
# Check the figure in ../output_figures/NL/Transport demand...
# Check the figure in ../output_figures/PL/Transport demand...
# Check the figure in ../output_figures/PT/Transport demand...
# Check the figure in ../output_figures/RO/Transport demand...
# Check the figure in ../output_figures/SE/Transport demand...
# Check the figure in ../output_figures/SI/Transport demand...
# Check the figure in ../output_figures/SK/Transport demand...
